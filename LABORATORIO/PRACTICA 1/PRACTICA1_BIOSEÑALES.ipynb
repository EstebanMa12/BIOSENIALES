# %% [markdown]
# #INTRODUCCIÓN AL USO DE PYTHON Y NUMPY

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# - a) Cree el siguiente par de vectores:
#
# a = [3.1,1, -0.5, -3.2, 6], b= [1, 3, 2.2, 5.1, 1]

# %%
a=np.array([3.1,1, -0.5, -3.2, 6]);
b=np.array([1, 3, 2.2, 5.1, 1])

# %%
a,b
# Out:
# (array([ 3.1,  1. , -0.5, -3.2,  6. ]), array([1. , 3. , 2.2, 5.1, 1. ]))

# %% [markdown]
# - b) Implemente la multiplicación escalar de a.b ¿Qué se debe realizar para poder multiplicar los dos vectores?

# %%
ab= np.dot(a,b) #
print(ab)
# Out:
# -5.32

# %% [markdown]
# - c) Implemente la multiplicación punto a punto de a.b

# %%
c= a*b
print(c)
# Out:
# [  3.1    3.    -1.1  -16.32   6.  ]

# %% [markdown]
# - d) Construya la siguiente matriz:
#
# 𝐴=[2−1−3 41.5−2.57.3−0.90.2]

# %%
A= np.array([[2,-1,-3],[4,1.5,-2.5],[7.3,-0.9, 0.2]])
print(A),print(type(A))
# Out:
# [[ 2.  -1.  -3. ]
#  [ 4.   1.5 -2.5]
#  [ 7.3 -0.9  0.2]]
# <class 'numpy.ndarray'>
# (None, None)

# %% [markdown]
# - e) Obtenga su transpuesta AT.

# %%
AT=np.transpose(A)
print(AT)
# Out:
# [[ 2.   4.   7.3]
#  [-1.   1.5 -0.9]
#  [-3.  -2.5  0.2]]

# %% [markdown]
# - f) Consulte la función de los siguientes comandos de la librería numpy: ones, round, ceil, floor, implemente cada función para ejemplificar su uso.

# %%
one= np.ones((2,3))
print(one)
# Out:
# [[1. 1. 1.]
#  [1. 1. 1.]]

# %%
h= 2.8951
print(np.round(h,2))
# Out:
# 2.9

# %%
ceil_array=np.array([0.2,0.325,40.5,-15.6,-5.26,5.12,-6.321]) # La función de ceil permite en un arreglo de números aproximar al número entero siguiente más alto
print(np.ceil(ceil_array))#EJEMPLO
# Out:
# [  1.   1.  41. -15.  -5.   6.  -6.]

# %%
floor_array=np.array([0.2,0.325,40.5,-15.6,-5.26,5.12,-6.321]) # La función de floor permite en un arreglo de números aproximar al número entero anterior
print(np.floor(floor_array)) #EJEMPLO
# Out:
# [  0.   0.  40. -16.  -6.   5.  -7.]

# %% [markdown]
#   - g) Acceda al valor de la primera fila, tercera columna de la matriz A, imprímalo en consola.

# %%
print(A)
# Out:
# [[ 2.  -1.  -3. ]
#  [ 4.   1.5 -2.5]
#  [ 7.3 -0.9  0.2]]

# %%
print(A[0][2])
# Out:
# -3.0

# %% [markdown]
# - h) Obtenga la segunda fila de dicha matriz, imprímalo en consola.

# %%
print(A[1])
# Out:
# [ 4.   1.5 -2.5]

# %% [markdown]
# - i) Consulte el comando para conocer las dimensiones de una matriz, utilícelo con la matriz A e imprímalo en consola.

# %%
# Con el comando shape es posible acceder a las dimensiones del array 
A.shape
# Out:
# (3, 3)

# %% [markdown]
# - j) Construya la función 𝑦[𝑛]=sin⁡(𝜋∗0.12𝑛) en el intervalo 0 <= n <= 100.

# %%
t= np.arange(0,101)
y= np.sin(np.pi*0.12*t)
plt.plot(t,y)

# %% [markdown]
# - k) Construya otra senoidal 𝑦2[𝑛]=cos(2𝜋∗0.03𝑛)

# %%
y2= np.cos(2*np.pi*0.03*t)
plt.plot(t,y2)

# %% [markdown]
# - l) Genere una tercera señal que sea la suma de estas dos señales, es decir 𝑠[𝑛]=y[n]+𝑦2[𝑛] y una cuarta, que sea el producto de estas, 𝑡[𝑛]=y[n].𝑦2[𝑛].

# %%
s = y+y2
graf=plt.plot(t,s)
graf

# %%
tn= y*y2
plt.plot(t,tn)

# %% [markdown]
# - m) Graficar en la misma figura las señales y[n] y y2[n], utilice leyenda y colores diferentes para cada señal. Asigne título a cada eje.

# %%
plt.figure('Señales')
plt.plot(t,y,'-r')
plt.plot(t,y2,'-b')
plt.xlabel('Tiempo(s)')
plt.ylabel('Amplitud')
# Out:
# Text(0, 0.5, 'Amplitud')

# %% [markdown]
# - Graficar en la misma figura las señales s[n] y t[n], utilice leyenda y colores diferentes para cada señal. Asigne título a cada eje.

# %%
plt.figure('Señales')
plt.plot(t,s,'-g')
plt.plot(t,tn,'-m')
plt.xlabel('Tiempo(s)')
plt.ylabel('Amplitud')
# Out:
# Text(0, 0.5, 'Amplitud')
